# %% [markdown]
# # 1st week's homework - by [Aleksei Novikov](https://www.linkedin.com/in/devnovikov/)

# %% [markdown]
# ## Preparation

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Q1. Pandas version

# %%
pd.__version__
# Out:
# '2.3.2'

# %%
df = pd.read_csv("./car_fuel_efficiency.csv")

# %%
df.head(2)
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive        0.0
# 1          17.8        2007     USA  Gasoline  Front-wheel drive        0.0
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217

# %% [markdown]
# ## Q2. Records count
# How many records are in the dataset?
# - 9704

# %%
print(f"count of records {df.shape[0]} with {df.shape[1]} columns")
# Out:
# count of records 9704 with 11 columns

# %% [markdown]
# ## Q3. Fuel types
#
# How many fuel types are presented in the dataset?
# - 2

# %%
print(f"Answer: {df['fuel_type'].nunique()}")
# Out:
# Answer: 2

# %% [markdown]
# ## Q4. Missing values
#
# How many columns in the dataset have missing values?
#
# - 4

# %%
print(f"Answer: {df.isnull().any().sum()}")
# Out:
# Answer: 4

# %% [markdown]
# ## Q5. Max fuel efficiency
#
# What's the maximum fuel efficiency of cars from Asia?
#
# - 23.75

# %%
answer = df[df["origin"] == "Asia"]["fuel_efficiency_mpg"].max()
print(f"Answer: {answer}")
# Out:
# Answer: 23.759122836520497

# %% [markdown]
# ## Q6. Median value of horsepower
#
# 1. Find the median value of the `horsepower` column in the dataset.
# 2. Next, calculate the most frequent value of the same `horsepower` column.
# 3. Use the `fillna` method to fill the missing values in the `horsepower` column with the most frequent value from the previous step.
# 4. Now, calculate the median value of `horsepower` once again.
#
# Has it changed?
#
#
# - Yes, it increased

# %%
median = df["horsepower"].median()
print(f"1. Median: {median}")

value_counts = df["horsepower"].value_counts()
most_frequent_value = value_counts.idxmax()
most_frequent_value_times = value_counts.max()
na_count   = df["horsepower"].isna().sum()

print(f"2. Value {most_frequent_value} meet {most_frequent_value_times} times. NaN count: {na_count}")

new_values = df["horsepower"].fillna(most_frequent_value, inplace=False)

new_median = new_values.median()
print(f"4. Calculated median: {new_median}")

print(f"Answer: New median > old median: {new_median > median}")
# Out:
# 1. Median: 149.0
# 2. Value 152.0 meet 142 times. NaN count: 708
# 4. Calculated median: 152.0
# Answer: New median > old median: True

# %% [markdown]
# ## Q7. Sum of weights
#
# 1. Select all the cars from Asia
# 2. Select only columns `vehicle_weight` and `model_year`
# 3. Select the first 7 values
# 4. Get the underlying NumPy array. Let's call it `X`.
# 5. Compute matrix-matrix multiplication between the transpose of `X` and `X`. To get the transpose, use `X.T`. Let's call the result `XTX`.
# 6. Invert `XTX`.
# 7. Create an array `y` with values `[1100, 1300, 800, 900, 1000, 1100, 1200]`.
# 8. Multiply the inverse of `XTX` with the transpose of `X`, and then multiply the result by `y`. Call the result `w`.
# 9. What's the sum of all the elements of the result?
#
# > **Note**: You just implemented linear regression. We'll talk about it in the next lesson.
#
#
# - 0.51

# %%
# 1,2,3,4
X = df.query("origin=='Asia'")[['vehicle_weight', 'model_year']].head(7).to_numpy()

# 5
XTX = X.T @ X

# 6
XTX_inv = np.linalg.inv(XTX)

# 7
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

# 8
w = XTX_inv @ X.T @ y

# 9
print(f"Answer:{w.sum()}")
# Out:
# Answer:0.5187709081074025
